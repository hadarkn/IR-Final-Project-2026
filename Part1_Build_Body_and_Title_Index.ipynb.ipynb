# %%
import pyspark
import sys
from collections import Counter, OrderedDict
import itertools
from itertools import islice, count, groupby
import pandas as pd
import os
import re
from operator import itemgetter
from time import time
from pathlib import Path
import pickle
from google.cloud import storage
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf, SparkFiles
from pyspark.sql import SQLContext
import math

BUCKET_NAME = 'ir-wiki-hadar' 

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

english_stopwords = frozenset(stopwords.words('english'))
corpus_stopwords = ["category", "references", "also", "external", "links", 
                    "may", "first", "see", "history", "people", "one", "two", 
                    "part", "thumb", "including", "second", "following", 
                    "many", "however", "would", "became"]
all_stopwords = english_stopwords.union(corpus_stopwords)
RE_WORD = re.compile(r"""[\#\@\w](['\-]?\w){2,24}""", re.UNICODE)

sc.addFile("/home/dataproc/inverted_index_gcp.py")
sys.path.insert(0,SparkFiles.getRootDirectory())
from inverted_index_gcp import InvertedIndex
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 26/01/08 15:42:42 WARN org.apache.spark.SparkContext: The path /home/dataproc/inverted_index_gcp.py has been added already. Overwriting of added paths is not supported in the current version.

# %%
full_path = "gs://ir-wiki-hadar/multistream*_preprocessed.parquet"

parquetFile = spark.read.parquet(full_path)


id_title_pairs = parquetFile.select("id", "title").rdd
id_to_title_dict = id_title_pairs.collectAsMap()

with open('id_to_title.pkl', 'wb') as f:
    pickle.dump(id_to_title_dict, f)
    
client = storage.Client()
bucket = client.bucket(BUCKET_NAME)
blob = bucket.blob('id_to_title.pkl')
blob.upload_from_filename('id_to_title.pkl')

print("Saved id_to_title.pkl to bucket!")
# Out:
# Saved id_to_title.pkl to bucket!

# %%
import math

def calculate_norm(text):
    tokens = [m.group() for m in RE_WORD.finditer(text.lower())]
    tokens = [t for t in tokens if t not in all_stopwords]
    return math.sqrt(len(tokens))

doc_norms_rdd = parquetFile.select("id", "text").rdd.map(lambda x: (x.id, calculate_norm(x.text)))
doc_norms_dict = doc_norms_rdd.collectAsMap()

with open('doc_norms.pkl', 'wb') as f:
    pickle.dump(doc_norms_dict, f)

blob = bucket.blob('doc_norms.pkl')
blob.upload_from_filename('doc_norms.pkl')

print("Saved doc_norms.pkl to bucket!")
# Out:
# Saved doc_norms.pkl to bucket!

# %%
pr_csv_path = "gs://ir-wiki-hadar/pr/*" 
pr_df = spark.read.csv(pr_csv_path)

pr_rdd = pr_df.rdd.map(lambda x: (int(x[0]), float(x[1])))
pr_dict = pr_rdd.collectAsMap()

with open('page_rank.pkl', 'wb') as f:
    pickle.dump(pr_dict, f)

blob = bucket.blob('page_rank.pkl')
blob.upload_from_filename('page_rank.pkl')

print("Saved page_rank.pkl to bucket!")
# Out:
# Saved page_rank.pkl to bucket!

# %%
import os
from contextlib import closing
import itertools
from pathlib import Path
import pickle
from collections import defaultdict
import hashlib

BLOCK_SIZE = 1999998
TUPLE_SIZE = 6
TF_MASK = 2 ** 16 - 1

def _hash(s):
    return hashlib.blake2b(bytes(s, encoding='utf8'), digest_size=5).hexdigest()

def get_bucket(bucket_name):
    return storage.Client().bucket(bucket_name)

class MultiFileWriter:
    def __init__(self, base_dir, name, bucket_name=None):
        self._base_dir = Path(base_dir)
        self._name = name
        self._bucket = None if bucket_name is None else get_bucket(bucket_name)
        self._file_gen = itertools.count()
        self._f = None
        self._current_part = -1
        self._next_file()

    def _next_file(self):
        if self._f:
            self._f.close()
            self._upload_file(self._f.name)
        
        self._current_part = next(self._file_gen)
        fname = f'{self._name}_{self._current_part:03}.bin'
        self._f = open(fname, 'wb') 
        self._current_blob_name = str(self._base_dir / fname)

    def _upload_file(self, local_filename):
        if self._bucket:
            blob = self._bucket.blob(self._current_blob_name)
            blob.upload_from_filename(local_filename)
        if os.path.exists(local_filename):
            os.remove(local_filename)

    def write(self, b):
        locs = []
        while len(b) > 0:
            pos = self._f.tell()
            remaining = BLOCK_SIZE - pos
            if remaining == 0:
                self._next_file()
                pos, remaining = 0, BLOCK_SIZE
            self._f.write(b[:remaining])
            locs.append((self._current_blob_name, pos))
            b = b[remaining:]
        return locs

    def close(self):
        if self._f:
            self._f.close()
            self._upload_file(self._f.name)

def write_a_posting_list(b_w_pl, base_dir, bucket_name=None):
    posting_locs = defaultdict(list)
    bucket_id, list_w_pl = b_w_pl
    
    with closing(MultiFileWriter(base_dir, bucket_id, bucket_name)) as writer:
        for w, pl in list_w_pl: 
            b = b''.join([(doc_id << 16 | (tf & TF_MASK)).to_bytes(TUPLE_SIZE, 'big')
                          for doc_id, tf in pl])
            locs = writer.write(b)
            posting_locs[w].extend(locs)
    
    path = str(Path(base_dir) / f'{bucket_id}_posting_locs.pickle')
    local_pickle_path = f'{bucket_id}_posting_locs.pickle'
    with open(local_pickle_path, 'wb') as f:
        pickle.dump(posting_locs, f)
    
    if bucket_name:
        bucket = get_bucket(bucket_name)
        blob = bucket.blob(path)
        blob.upload_from_filename(local_pickle_path)
        if os.path.exists(local_pickle_path):
            os.remove(local_pickle_path)
            
    return bucket_id

NUM_BUCKETS = 124
def token2bucket_id(token):
    return int(_hash(token),16) % NUM_BUCKETS

def word_count_title(doc_id, text):
    tokens = [m.group() for m in RE_WORD.finditer(text.lower())]
    tokens = [t for t in tokens if t not in all_stopwords]
    return [(token, (doc_id, tf)) for token, tf in Counter(tokens).items()]

def reduce_word_counts(unsorted_pl):
    return sorted(unsorted_pl, key=lambda x: x[0])

def calculate_df(postings):
    return postings.mapValues(lambda posting_list: len(posting_list))

def partition_postings_and_write(postings, base_name):
    bucketed = postings.map(lambda x: (token2bucket_id(x[0]), (x[0], x[1])))
    buckets = bucketed.groupByKey()
    def write_bucket(bucket):
        bucket_id, token_postings = bucket
        return write_a_posting_list((bucket_id, list(token_postings)), base_name, BUCKET_NAME)
    return buckets.map(write_bucket)

print("Starting Title Indexing (Patched Version)...")
title_counts = parquetFile.select("id", "title").rdd.flatMap(lambda x: word_count_title(x.id, x.title))
title_postings = title_counts.groupByKey().mapValues(reduce_word_counts)

w2df_title = calculate_df(title_postings)
w2df_title_dict = w2df_title.collectAsMap()

_ = partition_postings_and_write(title_postings, "title_index").collect()

index_title = InvertedIndex()
index_title.df = w2df_title_dict
index_title.write_index('.', 'index_title')

# !gsutil cp index_title.pkl gs://{BUCKET_NAME}/title_index/index.pkl

print("Title Index Done!")
# Out:
# Starting Title Indexing (Patched Version)...
# Copying file://index_title.pkl [Content-Type=application/octet-stream]...
# / [1 files][ 23.0 MiB/ 23.0 MiB]
# Operation completed over 1 objects/23.0 MiB.
# Title Index Done!

# %%
print("Starting Anchor Indexing...")

anchor_docs = parquetFile.select("id", "anchor_text").rdd.flatMap(lambda x: 
    [(link['id'], link['text']) for link in x.anchor_text if link['id'] is not None and link['text'] is not None]
)

anchor_text_grouped = anchor_docs.reduceByKey(lambda x,y: x + " " + y)


anchor_counts = anchor_text_grouped.flatMap(lambda x: word_count_title(x[0], x[1]))
anchor_postings = anchor_counts.groupByKey().mapValues(reduce_word_counts)

_ = partition_postings_and_write(anchor_postings, "anchor_index").collect()

w2df_anchor = calculate_df(anchor_postings)
w2df_anchor_dict = w2df_anchor.collectAsMap()

index_anchor = InvertedIndex()
index_anchor.df = w2df_anchor_dict
index_anchor.write_index('.', 'index_anchor')

# !gsutil cp index_anchor.pkl gs://{BUCKET_NAME}/anchor_index/index.pkl

print("Anchor Index Done!")
# Out:
# Starting Anchor Indexing...
# Copying file://index_anchor.pkl [Content-Type=application/octet-stream]...
# - [1 files][ 32.4 MiB/ 32.4 MiB]
# Operation completed over 1 objects/32.4 MiB.
# Anchor Index Done!

# %%
# !gsutil ls -lh gs://ir-wiki-hadar/**
# Out:
#   1.91 MiB  2026-01-08T16:23:07Z  gs://ir-wiki-hadar/anchor_index/0_000.bin
#   1.91 MiB  2026-01-08T16:23:07Z  gs://ir-wiki-hadar/anchor_index/0_001.bin
#   1.91 MiB  2026-01-08T16:23:08Z  gs://ir-wiki-hadar/anchor_index/0_002.bin
#   1.67 MiB  2026-01-08T16:23:08Z  gs://ir-wiki-hadar/anchor_index/0_003.bin
# 498.05 KiB  2026-01-08T16:23:08Z  gs://ir-wiki-hadar/anchor_index/0_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/100_000.bin
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/100_001.bin
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/100_002.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/100_003.bin
#   1.17 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/100_004.bin
# 509.62 KiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/100_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/101_000.bin
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/101_001.bin
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/101_002.bin
# 844.22 KiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/101_003.bin
#  502.2 KiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/101_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/102_000.bin
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/102_001.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/102_002.bin
#   1.38 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/102_003.bin
# 510.55 KiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/102_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:31Z  gs://ir-wiki-hadar/anchor_index/103_000.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/103_001.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/103_002.bin
# 1019.89 KiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/103_003.bin
# 494.69 KiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/103_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/104_000.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/104_001.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/104_002.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/104_003.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/104_004.bin
#   1.14 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/104_005.bin
# 503.96 KiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/104_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/105_000.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/105_001.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/105_002.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/105_003.bin
# 362.03 KiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/105_004.bin
# 495.07 KiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/105_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/106_000.bin
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/106_001.bin
#   1.15 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/106_002.bin
# 496.52 KiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/106_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/107_000.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/107_001.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/107_002.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/107_003.bin
# 936.13 KiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/107_004.bin
# 501.42 KiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/107_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:32Z  gs://ir-wiki-hadar/anchor_index/108_000.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/108_001.bin
#   1.54 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/108_002.bin
# 498.75 KiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/108_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/109_000.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/109_001.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/109_002.bin
#   1.53 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/109_003.bin
# 511.69 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/109_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:09Z  gs://ir-wiki-hadar/anchor_index/10_000.bin
#   1.91 MiB  2026-01-08T16:23:09Z  gs://ir-wiki-hadar/anchor_index/10_001.bin
#   1.91 MiB  2026-01-08T16:23:10Z  gs://ir-wiki-hadar/anchor_index/10_002.bin
#   1.25 MiB  2026-01-08T16:23:10Z  gs://ir-wiki-hadar/anchor_index/10_003.bin
# 503.42 KiB  2026-01-08T16:23:10Z  gs://ir-wiki-hadar/anchor_index/10_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/110_000.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/110_001.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/110_002.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/110_003.bin
#   1.18 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/110_004.bin
# 495.91 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/110_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/111_000.bin
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/111_001.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/111_002.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/111_003.bin
# 510.35 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/111_004.bin
# 501.23 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/111_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:33Z  gs://ir-wiki-hadar/anchor_index/112_000.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/112_001.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/112_002.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/112_003.bin
# 758.99 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/112_004.bin
# 502.66 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/112_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/113_000.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/113_001.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/113_002.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/113_003.bin
#  28.91 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/113_004.bin
# 493.96 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/113_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/114_000.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/114_001.bin
#   1.33 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/114_002.bin
# 496.52 KiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/114_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/115_000.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/115_001.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/115_002.bin
# 952.35 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/115_003.bin
#  501.5 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/115_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/116_000.bin
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/116_001.bin
#   1.91 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/116_002.bin
#   1.25 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/116_003.bin
# 496.99 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/116_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:34Z  gs://ir-wiki-hadar/anchor_index/117_000.bin
#   1.91 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/117_001.bin
# 751.43 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/117_002.bin
# 502.85 KiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/117_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/118_000.bin
#   1.91 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/118_001.bin
#   1.91 MiB  2026-01-08T16:23:36Z  gs://ir-wiki-hadar/anchor_index/118_002.bin
#   1.64 MiB  2026-01-08T16:23:36Z  gs://ir-wiki-hadar/anchor_index/118_003.bin
# 502.95 KiB  2026-01-08T16:23:36Z  gs://ir-wiki-hadar/anchor_index/118_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/119_000.bin
#   1.91 MiB  2026-01-08T16:23:35Z  gs://ir-wiki-hadar/anchor_index/119_001.bin
#   1.91 MiB  2026-01-08T16:23:36Z  gs://ir-wiki-hadar/anchor_index/119_002.bin
#   1.91 MiB  2026-01-08T16:23:36Z  gs://ir-wiki-hadar/anchor_index
#   1.91 MiB  2026-01-08T16:23:26Z  gs://ir-wiki-hadar/anchor_index/82_001.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/82_002.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/82_003.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/82_004.bin
# 143.99 KiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/82_005.bin
# 505.67 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/82_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:26Z  gs://ir-wiki-hadar/anchor_index/83_000.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/83_001.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/83_002.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/83_003.bin
#   1.19 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/83_004.bin
#  508.9 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/83_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:26Z  gs://ir-wiki-hadar/anchor_index/84_000.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/84_001.bin
#   1.85 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/84_002.bin
# 498.31 KiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/84_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/85_000.bin
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/85_001.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/85_002.bin
# 755.07 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/85_003.bin
# 502.52 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/85_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/86_000.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/86_001.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/86_002.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/86_003.bin
# 713.64 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/86_004.bin
# 507.06 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/86_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:27Z  gs://ir-wiki-hadar/anchor_index/87_000.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/87_001.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/87_002.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/87_003.bin
# 175.04 KiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/87_004.bin
# 502.71 KiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/87_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/88_000.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/88_001.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/88_002.bin
#   1.41 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/88_003.bin
#  501.8 KiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/88_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/89_000.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/89_001.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/89_002.bin
#   1.91 MiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/89_003.bin
#  30.92 KiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/89_004.bin
# 495.03 KiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/89_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:09Z  gs://ir-wiki-hadar/anchor_index/8_000.bin
#   1.91 MiB  2026-01-08T16:23:09Z  gs://ir-wiki-hadar/anchor_index/8_001.bin
#   1.91 MiB  2026-01-08T16:23:10Z  gs://ir-wiki-hadar/anchor_index/8_002.bin
#    1.9 MiB  2026-01-08T16:23:10Z  gs://ir-wiki-hadar/anchor_index/8_003.bin
# 511.19 KiB  2026-01-08T16:23:10Z  gs://ir-wiki-hadar/anchor_index/8_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/90_000.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/90_001.bin
#   1.91 MiB  2026-01-08T16:23:28Z  gs://ir-wiki-hadar/anchor_index/90_002.bin
#   1.44 MiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/90_003.bin
# 495.79 KiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/90_posting_locs.pickle
#   1.91 MiB  2026-01-08T16:23:29Z  gs://ir-wiki-hadar/anchor_index/91_000.bin
# ...
# 322.17 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/12_posting_locs.pickle
# 668.01 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/13_000.bin
# 326.79 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/13_posting_locs.pickle
# 665.61 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/14_000.bin
# 325.63 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/14_posting_locs.pickle
# 545.46 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/15_000.bin
# 329.95 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/15_posting_locs.pickle
#  824.7 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/16_000.bin
# 325.75 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/16_posting_locs.pickle
# 872.89 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/17_000.bin
# 326.07 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/17_posting_locs.pickle
#  654.9 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/18_000.bin
# 322.23 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/18_posting_locs.pickle
#  724.4 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/19_000.bin
#  325.2 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/19_posting_locs.pickle
# 711.59 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/1_000.bin
# 327.27 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/1_posting_locs.pickle
# 910.24 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/20_000.bin
# 329.95 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/20_posting_locs.pickle
# 716.78 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/21_000.bin
#  323.5 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/21_posting_locs.pickle
#  704.6 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/22_000.bin
# 327.25 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/22_posting_locs.pickle
# 699.93 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/23_000.bin
# 328.38 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/23_posting_locs.pickle
# 591.36 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/24_000.bin
# 326.49 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/24_posting_locs.pickle
# 798.26 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/25_000.bin
# 324.32 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/25_posting_locs.pickle
# 786.16 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/26_000.bin
# 330.66 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/26_posting_locs.pickle
# 627.93 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/27_000.bin
# 330.78 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/27_posting_locs.pickle
#  822.2 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/28_000.bin
# 326.09 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/28_posting_locs.pickle
# 718.86 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/29_000.bin
#  324.2 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/29_posting_locs.pickle
# 633.51 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/2_000.bin
# 325.98 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/2_posting_locs.pickle
# 934.24 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/30_000.bin
# 327.06 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/30_posting_locs.pickle
# 576.06 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/31_000.bin
# 325.13 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/31_posting_locs.pickle
#  674.4 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/32_000.bin
# 327.71 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/32_posting_locs.pickle
# 700.69 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/33_000.bin
# 323.69 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/33_posting_locs.pickle
# 800.01 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/34_000.bin
# 328.21 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/34_posting_locs.pickle
# 792.73 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/35_000.bin
# 327.15 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/35_posting_locs.pickle
# 629.21 KiB  2026-01-08T16:06:43Z  gs://ir-wiki-hadar/title_index/36_000.bin
# 322.95 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/36_posting_locs.pickle
# 789.61 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/37_000.bin
# 328.46 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/37_posting_locs.pickle
# 914.79 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/38_000.bin
# 326.01 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/38_posting_locs.pickle
# 784.01 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/39_000.bin
# 325.59 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/39_posting_locs.pickle
# 589.75 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/3_000.bin
# 327.65 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/3_posting_locs.pickle
# 891.73 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/40_000.bin
# 326.52 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/40_posting_locs.pickle
# 764.24 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/41_000.bin
# 327.28 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/41_posting_locs.pickle
# 1013.41 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/42_000.bin
#  328.3 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/42_posting_locs.pickle
# 629.64 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/43_000.bin
# 327.17 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/43_posting_locs.pickle
# 794.74 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/44_000.bin
# 328.25 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/44_posting_locs.pickle
# 669.53 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/45_000.bin
# 329.91 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/45_posting_locs.pickle
# 583.78 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/46_000.bin
# 324.09 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/46_posting_locs.pickle
# 610.61 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/47_000.bin
# 326.65 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/47_posting_locs.pickle
# 811.83 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/48_000.bin
# 329.91 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/48_posting_locs.pickle
#  623.5 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/49_000.bin
# 326.99 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/49_posting_locs.pickle
# 821.27 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/4_000.bin
# 328.39 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/4_posting_locs.pickle
# 742.27 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/50_000.bin
# 325.48 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/50_posting_locs.pickle
# 699.14 KiB  2026-01-08T16:06:44Z  gs://ir-wiki-hadar/title_index/51_000.bin
# 329.24 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/51_posting_locs.pickle
# 869.37 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/52_000.bin
#  324.6 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/52_posting_locs.pickle
# 806.71 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/53_000.bin
# 330.24 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/53_posting_locs.pickle
# 950.89 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/54_000.bin
# 322.15 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/54_posting_locs.pickle
# 890.33 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/55_000.bin
#  328.5 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/55_posting_locs.pickle
#   1.03 MiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/56_000.bin
# 327.77 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/56_posting_locs.pickle
# 881.18 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/57_000.bin
# 324.16 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/57_posting_locs.pickle
# 710.43 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/58_000.bin
# 331.62 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/58_posting_locs.pickle
# 758.23 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/59_000.bin
# 329.05 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/59_posting_locs.pickle
#  694.8 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/5_000.bin
# 334.55 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/5_posting_locs.pickle
# 820.01 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/60_000.bin
# 335.24 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/60_posting_locs.pickle
# 574.57 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/61_000.bin
# 324.69 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/61_posting_locs.pickle
# 647.09 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/62_000.bin
#  324.2 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/62_posting_locs.pickle
# 619.85 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/63_000.bin
#    327 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/63_posting_locs.pickle
# 616.42 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/64_000.bin
# 331.18 KiB  2026-01-08T16:06:45Z  gs://ir-wiki-hadar/title_index/64_posting_locs.pickle
# 784.42 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/65_000.bin
# 329.89 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/65_posting_locs.pickle
# 709.44 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/66_000.bin
#  330.1 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/66_posting_locs.pickle
#  812.1 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/67_000.bin
# 321.45 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/67_posting_locs.pickle
#   1.29 MiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/68_000.bin
# 329.26 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/68_posting_locs.pickle
# 600.57 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/69_000.bin
#  325.8 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/69_posting_locs.pickle
# 678.71 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/6_000.bin
# 327.32 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/6_posting_locs.pickle
# 751.54 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/70_000.bin
# 324.11 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/70_posting_locs.pickle
# 939.11 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/71_000.bin
# 329.26 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/71_posting_locs.pickle
#  829.8 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/72_000.bin
# 326.62 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/72_posting_locs.pickle
# 578.61 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/73_000.bin
# 327.71 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/73_posting_locs.pickle
# 845.47 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/74_000.bin
# 324.65 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/74_posting_locs.pickle
# 606.36 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/75_000.bin
# 324.79 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/75_posting_locs.pickle
# 657.08 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/76_000.bin
# 323.96 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/76_posting_locs.pickle
# 971.46 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/77_000.bin
# 328.57 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/77_posting_locs.pickle
#  562.2 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/78_000.bin
# 325.65 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/78_posting_locs.pickle
#  672.8 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/79_000.bin
#  326.1 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/79_posting_locs.pickle
# 981.75 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/7_000.bin
# 322.63 KiB  2026-01-08T16:06:41Z  gs://ir-wiki-hadar/title_index/7_posting_locs.pickle
#  562.7 KiB  2026-01-08T16:06:46Z  gs://ir-wiki-hadar/title_index/80_000.bin
# 324.21 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/80_posting_locs.pickle
# 871.77 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/81_000.bin
#  327.8 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/81_posting_locs.pickle
#   1.04 MiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/82_000.bin
# 330.47 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/82_posting_locs.pickle
# 829.49 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/83_000.bin
# 326.54 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/83_posting_locs.pickle
# 595.57 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/84_000.bin
# 330.55 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/84_posting_locs.pickle
# 608.93 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/85_000.bin
# 327.62 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/85_posting_locs.pickle
#  828.9 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/86_000.bin
# 333.08 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/86_posting_locs.pickle
# 672.04 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/87_000.bin
# 330.72 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/87_posting_locs.pickle
# 836.84 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/88_000.bin
#  327.6 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/88_posting_locs.pickle
# 814.77 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/89_000.bin
# 322.93 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/89_posting_locs.pickle
# 1000.01 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/8_000.bin
# 329.41 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/8_posting_locs.pickle
#  765.4 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/90_000.bin
# 324.02 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/90_posting_locs.pickle
# 693.74 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/91_000.bin
# 327.92 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/91_posting_locs.pickle
# 631.71 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/92_000.bin
# 330.42 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/92_posting_locs.pickle
# 701.59 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/93_000.bin
# 324.35 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/93_posting_locs.pickle
# 739.99 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/94_000.bin
# 327.88 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/94_posting_locs.pickle
# 785.09 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/95_000.bin
#  323.2 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/95_posting_locs.pickle
# 945.24 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/96_000.bin
# 326.72 KiB  2026-01-08T16:06:48Z  gs://ir-wiki-hadar/title_index/96_posting_locs.pickle
# 561.59 KiB  2026-01-08T16:06:47Z  gs://ir-wiki-hadar/title_index/97_000.bin
# 327.12 KiB  2026-01-08T16:06:48Z  gs://ir-wiki-hadar/title_index/97_posting_locs.pickle
# 840.11 KiB  2026-01-08T16:06:48Z  gs://ir-wiki-hadar/title_index/98_000.bin
#  326.8 KiB  2026-01-08T16:06:48Z  gs://ir-wiki-hadar/title_index/98_posting_locs.pickle
# 649.63 KiB  2026-01-08T16:06:48Z  gs://ir-wiki-hadar/title_index/99_000.bin
# 325.15 KiB  2026-01-08T16:06:48Z  gs://ir-wiki-hadar/title_index/99_posting_locs.pickle
# 643.88 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/9_000.bin
# 325.95 KiB  2026-01-08T16:06:42Z  gs://ir-wiki-hadar/title_index/9_posting_locs.pickle
#  22.97 MiB  2026-01-08T16:06:52Z  gs://ir-wiki-hadar/title_index/index.pkl
# TOTAL: 4328 objects, 23318959976 bytes (21.72 GiB)
